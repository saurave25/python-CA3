# %% [markdown]
# # CA3

# %% [markdown]
# # 1. Loading the dataset onto a DataFrame

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('IPL.csv')
df
# Out:
#      Sl.NO.   PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0         1   Abdulla, YA    2      SA   KXIP   Allrounder       0       0
# 1         2  Abdur Razzak    2     BAN    RCB       Bowler     214      18
# 2         3   Agarkar, AB    2     IND    KKR       Bowler     571      58
# 3         4     Ashwin, R    1     IND    CSK       Bowler     284      31
# 4         5  Badrinath, S    2     IND    CSK      Batsman      63       0
# ..      ...           ...  ...     ...    ...          ...     ...     ...
# 125     126     Yadav, AS    2     IND     DC      Batsman       0       0
# 126     127   Younis Khan    2     PAK     RR      Batsman    6398       7
# 127     128  Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128     129   Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129     130    Zoysa, DNT    2      SL     DC       Bowler     288      64
#
#      ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# 0             0      0.00  ...    0.00       0     307    15   20.47   8.90
# 1           657     71.41  ...    0.00       0      29     0    0.00  14.50
# 2          1269     80.62  ...  121.01       5    1059    29   36.52   8.81
# 3           241     84.56  ...   76.32       0    1125    49   22.96   6.23
# 4            79     45.93  ...  120.71      28       0     0    0.00   0.00
# ..          ...       ...  ...     ...     ...     ...   ...     ...    ...
# 125           0      0.00  ...  125.64       2       0     0    0.00   0.00
# 126        6814     75.78  ...   42.85       0       0     0    0.00   0.00
# 127        8051     87.58  ...  131.88      67     569    23   24.74   7.02
# 128         790     73.55  ...   91.67       1    1783    65   27.43   7.75
# 129         343     95.81  ...  122.22       0      99     2   49.50   9.00
#
#      SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# 0    13.93          2009       50000       50000
# 1     0.00          2008       50000       50000
# 2    24.90          2008      200000      350000
# 3    22.14          2011      100000      850000
# 4     0.00          2011      100000      800000
# ..     ...           ...         ...         ...
# 125   0.00          2010       50000      750000
# 126   0.00          2008      225000      225000
# 127  21.13          2011      400000     1800000
# 128  21.26          2008      200000      450000
# 129  33.00          2008      100000      110000
#
# [130 rows x 26 columns]

# %% [markdown]
# # 2. Displaying first few records of the DataFrame

# %%
df.head()
# Out:
#    Sl.NO.   PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0       1   Abdulla, YA    2      SA  KXIP   Allrounder       0       0
# 1       2  Abdur Razzak    2     BAN   RCB       Bowler     214      18
# 2       3   Agarkar, AB    2     IND   KKR       Bowler     571      58
# 3       4     Ashwin, R    1     IND   CSK       Bowler     284      31
# 4       5  Badrinath, S    2     IND   CSK      Batsman      63       0
#
#    ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# 0           0      0.00  ...    0.00       0     307    15   20.47   8.90
# 1         657     71.41  ...    0.00       0      29     0    0.00  14.50
# 2        1269     80.62  ...  121.01       5    1059    29   36.52   8.81
# 3         241     84.56  ...   76.32       0    1125    49   22.96   6.23
# 4          79     45.93  ...  120.71      28       0     0    0.00   0.00
#
#    SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# 0  13.93          2009       50000       50000
# 1   0.00          2008       50000       50000
# 2  24.90          2008      200000      350000
# 3  22.14          2011      100000      850000
# 4   0.00          2011      100000      800000
#
# [5 rows x 26 columns]

# %% [markdown]
# # 3. Finding metadata of the DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 26 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sl.NO.         130 non-null    int64
#  1   PLAYER NAME    130 non-null    object
#  2   AGE            130 non-null    int64
#  3   COUNTRY        130 non-null    object
#  4   TEAM           130 non-null    object
#  5   PLAYING ROLE   130 non-null    object
#  6   T-RUNS         130 non-null    int64
#  7   T-WKTS         130 non-null    int64
#  8   ODI-RUNS-S     130 non-null    int64
#  9   ODI-SR-B       130 non-null    float64
#  10  ODI-WKTS       130 non-null    int64
#  11  ODI-SR-BL      130 non-null    float64
#  12  CAPTAINCY EXP  130 non-null    int64
#  13  RUNS-S         130 non-null    int64
#  14  HS             130 non-null    int64
#  15  AVE            130 non-null    float64
#  16  SR-B           130 non-null    float64
#  17  SIXERS         130 non-null    int64
#  18  RUNS-C         130 non-null    int64
#  19  WKTS           130 non-null    int64
#  20  AVE-BL         130 non-null    float64
#  21  ECON           130 non-null    float64
#  22  SR-BL          130 non-null    float64
#  23  AUCTION YEAR   130 non-null    int64
#  24  BASE PRICE     130 non-null    int64
#  25  SOLD PRICE     130 non-null    int64
# dtypes: float64(7), int64(15), object(4)
# memory usage: 26.5+ KB

# %% [markdown]
# # 4. Finding Summary of the DataFrame

# %%
df.describe()
# Out:
#            Sl.NO.         AGE        T-RUNS      T-WKTS    ODI-RUNS-S  \
# count  130.000000  130.000000    130.000000  130.000000    130.000000
# mean    65.500000    2.092308   2166.715385   66.530769   2508.738462
# std     37.671829    0.576627   3305.646757  142.676855   3582.205625
# min      1.000000    1.000000      0.000000    0.000000      0.000000
# 25%     33.250000    2.000000     25.500000    0.000000     73.250000
# 50%     65.500000    2.000000    542.500000    7.000000    835.000000
# 75%     97.750000    2.000000   3002.250000   47.500000   3523.500000
# max    130.000000    3.000000  15470.000000  800.000000  18426.000000
#
#          ODI-SR-B    ODI-WKTS   ODI-SR-BL  CAPTAINCY EXP       RUNS-S  ...  \
# count  130.000000  130.000000  130.000000     130.000000   130.000000  ...
# mean    71.164385   76.076923   34.033846       0.315385   514.246154  ...
# std     25.898440  111.205070   26.751749       0.466466   615.226335  ...
# min      0.000000    0.000000    0.000000       0.000000     0.000000  ...
# 25%     65.650000    0.000000    0.000000       0.000000    39.000000  ...
# 50%     78.225000   18.500000   36.600000       0.000000   172.000000  ...
# 75%     86.790000  106.000000   45.325000       1.000000   925.250000  ...
# max    116.660000  534.000000  150.000000       1.000000  2254.000000  ...
#
#              SR-B      SIXERS       RUNS-C        WKTS      AVE-BL  \
# count  130.000000  130.000000   130.000000  130.000000  130.000000
# mean   111.053462   17.692308   475.523077   17.169231   23.110231
# std     35.928907   23.828146   558.314049   21.816763   20.802057
# min      0.000000    0.000000     0.000000    0.000000    0.000000
# 25%     98.237500    1.000000     0.000000    0.000000    0.000000
# 50%    118.510000    6.000000   297.000000    8.500000   24.785000
# 75%    129.102500   29.750000   689.250000   23.750000   35.580000
# max    235.490000  129.000000  1975.000000   83.000000  126.300000
#
#              ECON       SR-BL  AUCTION YEAR    BASE PRICE    SOLD PRICE
# count  130.000000  130.000000    130.000000  1.300000e+02  1.300000e+02
# mean     6.204462   17.382615   2009.092308  1.922308e+05  5.212231e+05
# std      4.941531   15.273422      1.377821  1.530973e+05  4.068074e+05
# min      0.000000    0.000000   2008.000000  2.000000e+04  2.000000e+04
# 25%      0.000000    0.000000   2008.000000  1.000000e+05  2.250000e+05
# 50%      7.380000   19.935000   2008.000000  2.000000e+05  4.375000e+05
# 75%      8.247500   26.212500   2011.000000  2.250000e+05  7.000000e+05
# max     38.110000  100.200000   2011.000000  1.350000e+06  1.800000e+06
#
# [8 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['Sl.NO.', 'PLAYER NAME', 'AGE', 'COUNTRY', 'TEAM', 'PLAYING ROLE',
#        'T-RUNS', 'T-WKTS', 'ODI-RUNS-S', 'ODI-SR-B', 'ODI-WKTS', 'ODI-SR-BL',
#        'CAPTAINCY EXP', 'RUNS-S', 'HS', 'AVE', 'SR-B', 'SIXERS', 'RUNS-C',
#        'WKTS', 'AVE-BL', 'ECON', 'SR-BL', 'AUCTION YEAR', 'BASE PRICE',
#        'SOLD PRICE'],
#       dtype='object')

# %% [markdown]
# # 5.Slicing and Indexing a dataframe

# %%
#Slicing the df using loc()
df.loc[:,"PLAYER NAME":"SOLD PRICE"]
# Out:
#       PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0     Abdulla, YA    2      SA   KXIP   Allrounder       0       0
# 1    Abdur Razzak    2     BAN    RCB       Bowler     214      18
# 2     Agarkar, AB    2     IND    KKR       Bowler     571      58
# 3       Ashwin, R    1     IND    CSK       Bowler     284      31
# 4    Badrinath, S    2     IND    CSK      Batsman      63       0
# ..            ...  ...     ...    ...          ...     ...     ...
# 125     Yadav, AS    2     IND     DC      Batsman       0       0
# 126   Younis Khan    2     PAK     RR      Batsman    6398       7
# 127  Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128   Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129    Zoysa, DNT    2      SL     DC       Bowler     288      64
#
#      ODI-RUNS-S  ODI-SR-B  ODI-WKTS  ...    SR-B  SIXERS  RUNS-C  WKTS  \
# 0             0      0.00         0  ...    0.00       0     307    15
# 1           657     71.41       185  ...    0.00       0      29     0
# 2          1269     80.62       288  ...  121.01       5    1059    29
# 3           241     84.56        51  ...   76.32       0    1125    49
# 4            79     45.93         0  ...  120.71      28       0     0
# ..          ...       ...       ...  ...     ...     ...     ...   ...
# 125           0      0.00         0  ...  125.64       2       0     0
# 126        6814     75.78         3  ...   42.85       0       0     0
# 127        8051     87.58       109  ...  131.88      67     569    23
# 128         790     73.55       278  ...   91.67       1    1783    65
# 129         343     95.81       108  ...  122.22       0      99     2
#
#      AVE-BL   ECON  SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# 0     20.47   8.90  13.93          2009       50000       50000
# 1      0.00  14.50   0.00          2008       50000       50000
# 2     36.52   8.81  24.90          2008      200000      350000
# 3     22.96   6.23  22.14          2011      100000      850000
# 4      0.00   0.00   0.00          2011      100000      800000
# ..      ...    ...    ...           ...         ...         ...
# 125    0.00   0.00   0.00          2010       50000      750000
# 126    0.00   0.00   0.00          2008      225000      225000
# 127   24.74   7.02  21.13          2011      400000     1800000
# 128   27.43   7.75  21.26          2008      200000      450000
# 129   49.50   9.00  33.00          2008      100000      110000
#
# [130 rows x 25 columns]

# %%
df.loc[:,['PLAYER NAME','T-RUNS','T-WKTS','SOLD PRICE']]
# Out:
#       PLAYER NAME  T-RUNS  T-WKTS  SOLD PRICE
# 0     Abdulla, YA       0       0       50000
# 1    Abdur Razzak     214      18       50000
# 2     Agarkar, AB     571      58      350000
# 3       Ashwin, R     284      31      850000
# 4    Badrinath, S      63       0      800000
# ..            ...     ...     ...         ...
# 125     Yadav, AS       0       0      750000
# 126   Younis Khan    6398       7      225000
# 127  Yuvraj Singh    1775       9     1800000
# 128   Zaheer Khan    1114     288      450000
# 129    Zoysa, DNT     288      64      110000
#
# [130 rows x 4 columns]

# %%
#Slicing using iloc()
df.iloc[::2]
# Out:
#      Sl.NO.   PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0         1   Abdulla, YA    2      SA  KXIP   Allrounder       0       0
# 2         3   Agarkar, AB    2     IND   KKR       Bowler     571      58
# 4         5  Badrinath, S    2     IND   CSK      Batsman      63       0
# 6         7     Balaji, L    2     IND  CSK+       Bowler      51      27
# 8         9      Botha, J    2      SA    RR   Allrounder      83      17
# ..      ...           ...  ...     ...   ...          ...     ...     ...
# 120     121   Vettori, DL    2      NZ   DD+   Allrounder    4486     359
# 122     123     Warne, SK    3     AUS    RR       Bowler    3154     708
# 124     125     White, CL    2     AUS  RCB+      Batsman     146       5
# 126     127   Younis Khan    2     PAK    RR      Batsman    6398       7
# 128     129   Zaheer Khan    2     IND   MI+       Bowler    1114     288
#
#      ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# 0             0      0.00  ...    0.00       0     307    15   20.47   8.90
# 2          1269     80.62  ...  121.01       5    1059    29   36.52   8.81
# 4            79     45.93  ...  120.71      28       0     0    0.00   0.00
# 6           120     78.94  ...   72.22       1    1342    52   25.81   7.98
# 8           609     85.77  ...  114.73       3     610    19   32.11   6.85
# ..          ...       ...  ...     ...     ...     ...   ...     ...    ...
# 120        2105     81.93  ...  107.08       2     878    28   31.36   6.81
# 122        1018     72.04  ...   92.52       6    1447    57   25.39   7.27
# 124        2037     80.48  ...  132.09      29      70     0    0.00  14.00
# 126        6814     75.78  ...   42.85       0       0     0    0.00   0.00
# 128         790     73.55  ...   91.67       1    1783    65   27.43   7.75
#
#      SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# 0    13.93          2009       50000       50000
# 2    24.90          2008      200000      350000
# 4     0.00          2011      100000      800000
# 6    19.40          2011      100000      500000
# 8    28.11          2011      200000      950000
# ..     ...           ...         ...         ...
# 120  27.75          2008      250000      625000
# 122  20.95          2008      450000      450000
# 124   0.00          2008      100000      500000
# 126   0.00          2008      225000      225000
# 128  21.26          2008      200000      450000
#
# [65 rows x 26 columns]

# %%
df.iloc[:, ::2]
# Out:
#      Sl.NO.  AGE   TEAM  T-RUNS  ODI-RUNS-S  ODI-WKTS  CAPTAINCY EXP  HS  \
# 0         1    2   KXIP       0           0         0              0   0
# 1         2    2    RCB     214         657       185              0   0
# 2         3    2    KKR     571        1269       288              0  39
# 3         4    1    CSK     284         241        51              0  11
# 4         5    2    CSK      63          79         0              0  71
# ..      ...  ...    ...     ...         ...       ...            ...  ..
# 125     126    2     DC       0           0         0              0  16
# 126     127    2     RR    6398        6814         3              1   3
# 127     128    2  KXIP+    1775        8051       109              1  66
# 128     129    2    MI+    1114         790       278              0  23
# 129     130    2     DC     288         343       108              0  10
#
#        SR-B  RUNS-C  AVE-BL  SR-BL  BASE PRICE
# 0      0.00     307   20.47  13.93       50000
# 1      0.00      29    0.00   0.00       50000
# 2    121.01    1059   36.52  24.90      200000
# 3     76.32    1125   22.96  22.14      100000
# 4    120.71       0    0.00   0.00      100000
# ..      ...     ...     ...    ...         ...
# 125  125.64       0    0.00   0.00       50000
# 126   42.85       0    0.00   0.00      225000
# 127  131.88     569   24.74  21.13      400000
# 128   91.67    1783   27.43  21.26      200000
# 129  122.22      99   49.50  33.00      100000
#
# [130 rows x 13 columns]

# %% [markdown]
# # 6.Selecting Columns by Column Names (eg: PLAYER NAME)

# %%
df.loc[:,['PLAYER NAME']]
# Out:
#       PLAYER NAME
# 0     Abdulla, YA
# 1    Abdur Razzak
# 2     Agarkar, AB
# 3       Ashwin, R
# 4    Badrinath, S
# ..            ...
# 125     Yadav, AS
# 126   Younis Khan
# 127  Yuvraj Singh
# 128   Zaheer Khan
# 129    Zoysa, DNT
#
# [130 rows x 1 columns]

# %% [markdown]
# # 7.Finding Unique Occurances of Values in Columns (eg: COUNTRY)

# %%
df['COUNTRY'].unique(drop)
# Out:
# array(['SA', 'BAN', 'IND', 'AUS', 'WI', 'SL', 'NZ', 'ENG', 'PAK', 'ZIM'],
#       dtype=object)

# %%
set(df['COUNTRY'])
# Out:
# {'AUS', 'BAN', 'ENG', 'IND', 'NZ', 'PAK', 'SA', 'SL', 'WI', 'ZIM'}

# %%
df[:].drop_duplicates()
# Out:
#      Sl.NO.   PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0         1   Abdulla, YA    2      SA   KXIP   Allrounder       0       0
# 1         2  Abdur Razzak    2     BAN    RCB       Bowler     214      18
# 2         3   Agarkar, AB    2     IND    KKR       Bowler     571      58
# 3         4     Ashwin, R    1     IND    CSK       Bowler     284      31
# 4         5  Badrinath, S    2     IND    CSK      Batsman      63       0
# ..      ...           ...  ...     ...    ...          ...     ...     ...
# 125     126     Yadav, AS    2     IND     DC      Batsman       0       0
# 126     127   Younis Khan    2     PAK     RR      Batsman    6398       7
# 127     128  Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128     129   Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129     130    Zoysa, DNT    2      SL     DC       Bowler     288      64
#
#      ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# 0             0      0.00  ...    0.00       0     307    15   20.47   8.90
# 1           657     71.41  ...    0.00       0      29     0    0.00  14.50
# 2          1269     80.62  ...  121.01       5    1059    29   36.52   8.81
# 3           241     84.56  ...   76.32       0    1125    49   22.96   6.23
# 4            79     45.93  ...  120.71      28       0     0    0.00   0.00
# ..          ...       ...  ...     ...     ...     ...   ...     ...    ...
# 125           0      0.00  ...  125.64       2       0     0    0.00   0.00
# 126        6814     75.78  ...   42.85       0       0     0    0.00   0.00
# 127        8051     87.58  ...  131.88      67     569    23   24.74   7.02
# 128         790     73.55  ...   91.67       1    1783    65   27.43   7.75
# 129         343     95.81  ...  122.22       0      99     2   49.50   9.00
#
#      SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# 0    13.93          2009       50000       50000
# 1     0.00          2008       50000       50000
# 2    24.90          2008      200000      350000
# 3    22.14          2011      100000      850000
# 4     0.00          2011      100000      800000
# ..     ...           ...         ...         ...
# 125   0.00          2010       50000      750000
# 126   0.00          2008      225000      225000
# 127  21.13          2011      400000     1800000
# 128  21.26          2008      200000      450000
# 129  33.00          2008      100000      110000
#
# [130 rows x 26 columns]

# %% [markdown]
# # 8. Cross-tabulation between two columns (eg: AGE & PLAYING ROLE)

# %%
pd.crosstab(df['AGE'],df['PLAYING ROLE'])
# Out:
# PLAYING ROLE  Allrounder  Batsman  Bowler  W. Keeper
# AGE
# 1                      4        5       7          0
# 2                     25       21      29         11
# 3                      6       13       8          1

# %% [markdown]
# # 9. Sorting dataframe by column values (eg: SOLD PRICE)

# %%
ndf=df.loc[:,['PLAYER NAME','SOLD PRICE']]
ndf.sort_values(by='SOLD PRICE',ascending=True)
# Out:
#        PLAYER NAME  SOLD PRICE
# 73      Noffke, AA       20000
# 46     Kamran Khan       24000
# 0      Abdulla, YA       50000
# 1     Abdur Razzak       50000
# 118  Van der Merwe       50000
# ..             ...         ...
# 113     Tiwary, SS     1600000
# 111  Tendulkar, SR     1800000
# 50        Kohli, V     1800000
# 93       Sehwag, V     1800000
# 127   Yuvraj Singh     1800000
#
# [130 rows x 2 columns]

# %% [markdown]
# # 10. Which player got the maximum premium on the base price?

# %%
df['PREMIUM']=df['SOLD PRICE']-df['BASE PRICE']
maxi=max(df['PREMIUM'])
df.loc[df['PREMIUM']==maxi]
# Out:
#     Sl.NO. PLAYER NAME  AGE COUNTRY TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 50      51    Kohli, V    1     IND  RCB      Batsman     491       0
#
#     ODI-RUNS-S  ODI-SR-B  ...  SIXERS  RUNS-C  WKTS  AVE-BL  ECON  SR-BL  \
# 50        3590     86.31  ...      49     345     4   86.25  8.84   58.5
#
#     AUCTION YEAR  BASE PRICE  SOLD PRICE  PREMIUM
# 50          2011      150000     1800000  1650000
#
# [1 rows x 27 columns]

# %% [markdown]
# # 11. Which players got the maximum premium offering on their base price?

# %%
df2=df.groupby('TEAM')
df2

# %% [markdown]
# # 12. What is the average SOLD PRICE for each age category?

# %%
df.groupby('AGE')['SOLD PRICE'].mean()
# Out:
# AGE
# 1    720250.000000
# 2    484534.883721
# 3    520178.571429
# Name: SOLD PRICE, dtype: float64

# %% [markdown]
# # 13. Average SOLD PRICE for Different Playing Roles in Each Age Category?

# %%
df.groupby(['AGE','PLAYING ROLE'])['SOLD PRICE'].mean()
# Out:
# AGE  PLAYING ROLE
# 1    Allrounder      5.875000e+05
#      Batsman         1.110000e+06
#      Bowler          5.177143e+05
# 2    Allrounder      4.494000e+05
#      Batsman         6.547619e+05
#      Bowler          3.979310e+05
#      W. Keeper       4.677273e+05
# 3    Allrounder      7.666667e+05
#      Batsman         4.576923e+05
#      Bowler          4.143750e+05
#      W. Keeper       7.000000e+05
# Name: SOLD PRICE, dtype: float64

# %% [markdown]
# # Practice

# %%
df['PLAYER NAME'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 130 entries, 0 to 129
# Series name: PLAYER NAME
# Non-Null Count  Dtype
# --------------  -----
# 130 non-null    object
# dtypes: object(1)
# memory usage: 1.1+ KB

# %%
df['AGE'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 130 entries, 0 to 129
# Series name: AGE
# Non-Null Count  Dtype
# --------------  -----
# 130 non-null    int64
# dtypes: int64(1)
# memory usage: 1.1 KB
